# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv("creditcard.csv")

# create a histogram of transaction amounts
plt.figure(figsize=(8, 6))
sns.histplot(df['Amount'], bins=50, kde=False)
plt.xlabel('Transaction Amount')
plt.ylabel('Count')
plt.title('Distribution of Transaction Amounts')
plt.xlim([0, df['Amount'].max()])
plt.show()

print("Minimum amount:", df['Amount'].min())
print("Maximum amount:", df['Amount'].max())
# Out:
# Minimum amount: 0.0
# Maximum amount: 25691.16

# %%
import seaborn as sns
import pandas as pd

sns.kdeplot(df['Amount'])
sns.despine(left=True)
plt.xlabel('Transaction Amount')
plt.title('Density Plot of Transaction Amounts')
plt.show()

# %%
# create boxplots of transaction amounts for fraudulent and non-fraudulent transactions
plt.figure(figsize=(8, 6))
sns.boxplot(x='Class', y='Amount', data=df)
plt.xlabel('Class (0 = Non-Fraudulent, 1 = Fraudulent)')
plt.ylabel('Transaction Amount')
plt.title('Comparison of Transaction Amounts for Fraudulent and Non-Fraudulent Transactions')
plt.show()

# %%
import seaborn as sns
import pandas as pd

data = pd.read_csv("creditcard.csv")

corr = data.corr()
sns.heatmap(corr, cmap="coolwarm")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V2'])
plt.xlabel('V1')
plt.ylabel('V2')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V3'])
plt.xlabel('V1')
plt.ylabel('V3')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V4'])
plt.xlabel('V1')
plt.ylabel('V4')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V5'])
plt.xlabel('V1')
plt.ylabel('V5')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V6'])
plt.xlabel('V1')
plt.ylabel('V6')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V7'])
plt.xlabel('V1')
plt.ylabel('V7')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V8'])
plt.xlabel('V1')
plt.ylabel('V8')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V9'])
plt.xlabel('V1')
plt.ylabel('V9')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V10'])
plt.xlabel('V1')
plt.ylabel('V10')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V11'])
plt.xlabel('V1')
plt.ylabel('V11')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V12'])
plt.xlabel('V1')
plt.ylabel('V12')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V13'])
plt.xlabel('V1')
plt.ylabel('V13')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V14'])
plt.xlabel('V1')
plt.ylabel('V14')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V15'])
plt.xlabel('V1')
plt.ylabel('V15')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V16'])
plt.xlabel('V1')
plt.ylabel('V16')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V17'])
plt.xlabel('V1')
plt.ylabel('V17')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V18'])
plt.xlabel('V1')
plt.ylabel('V18')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V19'])
plt.xlabel('V1')
plt.ylabel('V19')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V20'])
plt.xlabel('V1')
plt.ylabel('V20')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V21'])
plt.xlabel('V1')
plt.ylabel('V21')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V22'])
plt.xlabel('V1')
plt.ylabel('V22')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V23'])
plt.xlabel('V1')
plt.ylabel('V23')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V24'])
plt.xlabel('V1')
plt.ylabel('V24')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V25'])
plt.xlabel('V1')
plt.ylabel('V25')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V26'])
plt.xlabel('V1')
plt.ylabel('V26')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V27'])
plt.xlabel('V1')
plt.ylabel('V27')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.scatter(data['V1'], data['V28'])
plt.xlabel('V1')
plt.ylabel('V28')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

fraud_counts = data.groupby('Class')['Class'].count()
fraud_counts.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

fraud_counts = data.groupby('Class')['Class'].count()
fraud_counts.plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V1'], bins=50, density=True)
plt.xlabel('V1')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V2'], bins=50, density=True)
plt.xlabel('V2')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V3'], bins=50, density=True)
plt.xlabel('V3')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V4'], bins=50, density=True)
plt.xlabel('V4')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V5'], bins=50, density=True)
plt.xlabel('V5')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V6'], bins=50, density=True)
plt.xlabel('V6')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V7'], bins=50, density=True)
plt.xlabel('V7')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V8'], bins=50, density=True)
plt.xlabel('V8')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V9'], bins=50, density=True)
plt.xlabel('V9')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V10'], bins=50, density=True)
plt.xlabel('V10')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V11'], bins=50, density=True)
plt.xlabel('V11')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V12'], bins=50, density=True)
plt.xlabel('V12')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V13'], bins=50, density=True)
plt.xlabel('V13')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V14'], bins=50, density=True)
plt.xlabel('V14')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V15'], bins=50, density=True)
plt.xlabel('V15')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V16'], bins=50, density=True)
plt.xlabel('V16')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V17'], bins=50, density=True)
plt.xlabel('V17')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V18'], bins=50, density=True)
plt.xlabel('V18')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V19'], bins=50, density=True)
plt.xlabel('V19')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V20'], bins=50, density=True)
plt.xlabel('V20')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V21'], bins=50, density=True)
plt.xlabel('V21')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V22'], bins=50, density=True)
plt.xlabel('V22')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V23'], bins=50, density=True)
plt.xlabel('V23')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V24'], bins=50, density=True)
plt.xlabel('V24')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V25'], bins=50, density=True)
plt.xlabel('V25')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V26'], bins=50, density=True)
plt.xlabel('V26')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V27'], bins=50, density=True)
plt.xlabel('V27')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['V28'], bins=50, density=True)
plt.xlabel('V28')
plt.ylabel('Density')
plt.show()
